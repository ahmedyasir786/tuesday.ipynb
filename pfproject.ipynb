# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# # Remove rows

# %%
import pandas as pd
df = pd.read_csv('set.csv')
df
# Out:
#        Year  Literacy Rate(%) Population  Population growth rate (%)  \
# 0    1980.0              26.0  83,929,765                      2.47%
# 1    1981.0              27.0  86,154,836                      2.65%
# 2    1982.0              27.8  88,555,336                      2.79%
# 3    1983.0              28.2  91,045,478                      2.81%
# 4    1984.0              28.8  93,534,239                      2.73%
# ..      ...               ...         ...                        ...
# 96      NaN               NaN         NaN                        NaN
# 97      NaN               NaN         NaN                        NaN
# 98      NaN               NaN         NaN                        NaN
# 99      NaN               NaN         NaN                        NaN
# 100     NaN               NaN         NaN                        NaN
#
#     Migrant Population (Estimated)  Net Migration Rate Growth Rate  \
# 0                          720,000              -2.569      -8.38%
# ...

# %% [markdown]
# # Dropna

# %%
df.dropna
print(df)
# Out:
# Empty DataFrame
# ...

# %%
df.dropna()
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# # Inplace = true

# %%
df.dropna(inplace= True)

# %% [markdown]
# # Replace empty values with fillna()

# %%
df.fillna(45)
# Out:
# Empty DataFrame
# ...

# %%
df["Year"].fillna(10)
# Out:
# Series([], Name: Year, dtype: float64)

# %% [markdown]
# # Replace using mean, median and mode

# %%
x = df["Year"].mean()
df["Year"].fillna(x)
# Out:
# Series([], Name: Year, dtype: float64)

# %%
x = df["Growth Rate"].median()
df["Growth Rate"].fillna(x)
# Out:
# Series([], Name: Growth Rate, dtype: object)

# %%
x = df["Year"].mode()
df["Year"].fillna(x)
# Out:
# Series([], Name: Year, dtype: float64)

# %% [markdown]
# # Clearing data of wrong format

# %%
df['Year']
# Out:
# Series([], Name: Year, dtype: float64)

# %% [markdown]
# # Fixing wrong data

# %%
df['Year']
# Out:
# Series([], Name: Year, dtype: float64)

# %%
df.loc[1, 'Year'] = 1990
df['Year']
# Out:
# 1    1990.0
# Name: Year, dtype: float64

# %% [markdown]
# # Removing duplicates

# %%
df
# Out:
#      Year  Literacy Rate(%) Population  Population growth rate (%)  \
# 1  1990.0               NaN         NaN                        NaN
#
#   Migrant Population (Estimated)  Net Migration Rate Growth Rate  \
# 1                            NaN                 NaN         NaN
#
#   Inflation Rate (%) Annual Change (%)  GNI (Billion USD)  ... Military Size   \
# 1                NaN               NaN                NaN  ...            NaN
#
#   Annual % Change\r Suicide Rate Suicide Rate - Male Suicide Rate - Female  \
# 1               NaN          NaN                 NaN                   NaN
#
#   Education Spending (% of GDP) Annual Change.9 Arable Land -Hectares  \
# 1                           NaN             NaN                   NaN
#
#   Per Capita Percent
# 1        NaN     NaN
#
# [1 rows x 118 columns]

# %%
print(df.duplicated())
# Out:
# 1    False
# dtype: bool

# %% [markdown]
# # Drop duplicate

# %%
df.drop_duplicates()
# Out:
#      Year  Literacy Rate(%) Population  Population growth rate (%)  \
# 1  1990.0               NaN         NaN                        NaN
#
#   Migrant Population (Estimated)  Net Migration Rate Growth Rate  \
# 1                            NaN                 NaN         NaN
#
#   Inflation Rate (%) Annual Change (%)  GNI (Billion USD)  ... Military Size   \
# 1                NaN               NaN                NaN  ...            NaN
#
#   Annual % Change\r Suicide Rate Suicide Rate - Male Suicide Rate - Female  \
# 1               NaN          NaN                 NaN                   NaN
#
#   Education Spending (% of GDP) Annual Change.9 Arable Land -Hectares  \
# 1                           NaN             NaN                   NaN
#
#   Per Capita Percent
# 1        NaN     NaN
#
# [1 rows x 118 columns]

# %% [markdown]
# # Describe

# %%
df.describe()
# Out:
#          Year  Literacy Rate(%)  Net Migration Rate  GNI (Billion USD)  \
# count     1.0               0.0                 0.0                0.0
# mean   1990.0               NaN                 NaN                NaN
# std       NaN               NaN                 NaN                NaN
# min    1990.0               NaN                 NaN                NaN
# 25%    1990.0               NaN                 NaN                NaN
# 50%    1990.0               NaN                 NaN                NaN
# 75%    1990.0               NaN                 NaN                NaN
# max    1990.0               NaN                 NaN                NaN
#
#        Number of Private Vehichles  Death Rate  Life Expectancy (years)  \
# count                          0.0         0.0                      0.0
# mean                           NaN         NaN                      NaN
# std                            NaN         NaN                      NaN
# ...

# %% [markdown]
# # Adding new column in dataframe

# %%
df['col'] = 5
df
# Out:
#      Year  Literacy Rate(%) Population  Population growth rate (%)  \
# 1  1990.0               NaN         NaN                        NaN
#
#   Migrant Population (Estimated)  Net Migration Rate Growth Rate  \
# 1                            NaN                 NaN         NaN
#
#   Inflation Rate (%) Annual Change (%)  GNI (Billion USD)  ...  \
# 1                NaN               NaN                NaN  ...
#
#   Annual % Change\r Suicide Rate Suicide Rate - Male Suicide Rate - Female  \
# 1               NaN          NaN                 NaN                   NaN
#
#   Education Spending (% of GDP) Annual Change.9 Arable Land -Hectares  \
# 1                           NaN             NaN                   NaN
#
#   Per Capita Percent col
# 1        NaN     NaN   5
#
# [1 rows x 119 columns]

# %% [markdown]
# # Adding new row in dataframe

# %%
a = pd.DataFrame({'Year': 1991, 'Net Migration Rate': 6, 'Growth Rate': 17},index = [0])
a
# Out:
#    Year  Net Migration Rate  Growth Rate
# 0  1991                   6           17

# %% [markdown]
# # Data concatination

# %%
df = pd.concat([a, df])
df
# Out:
#      Year  Net Migration Rate Growth Rate  Literacy Rate(%) Population   \
# 0  1991.0                 6.0          17               NaN         NaN
# 1  1990.0                 NaN         NaN               NaN         NaN
#
#   Population growth rate (%) Migrant Population (Estimated)  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
#
#   Inflation Rate (%) Annual Change (%)  GNI (Billion USD)  ...  \
# 0                NaN               NaN                NaN  ...
# 1                NaN               NaN                NaN  ...
#
#   Annual % Change\r Suicide Rate Suicide Rate - Male Suicide Rate - Female  \
# 0               NaN          NaN                 NaN                   NaN
# 1               NaN          NaN                 NaN                   NaN
#
#   Education Spending (% of GDP) Annual Change.9 Arable Land -Hectares  \
# ...

# %% [markdown]
# # Row deletion in dataframe

# %%
df.drop(0, inplace=True)
df
# Out:
#      Year  Net Migration Rate Growth Rate  Literacy Rate(%) Population   \
# 1  1990.0                 NaN         NaN               NaN         NaN
#
#   Population growth rate (%) Migrant Population (Estimated)  \
# 1                        NaN                            NaN
#
#   Inflation Rate (%) Annual Change (%)  GNI (Billion USD)  ...  \
# 1                NaN               NaN                NaN  ...
#
#   Annual % Change\r Suicide Rate Suicide Rate - Male Suicide Rate - Female  \
# 1               NaN          NaN                 NaN                   NaN
#
#   Education Spending (% of GDP) Annual Change.9 Arable Land -Hectares  \
# 1                           NaN             NaN                   NaN
#
#   Per Capita Percent  col
# 1        NaN     NaN  5.0
#
# [1 rows x 119 columns]

# %% [markdown]
# # Slicing in pandas

# %%
df[0:4]
# Out:
#      Year  Net Migration Rate Growth Rate  Literacy Rate(%) Population   \
# 1  1990.0                 NaN         NaN               NaN         NaN
#
#   Population growth rate (%) Migrant Population (Estimated)  \
# 1                        NaN                            NaN
#
#   Inflation Rate (%) Annual Change (%)  GNI (Billion USD)  ...  \
# 1                NaN               NaN                NaN  ...
#
#   Annual % Change\r Suicide Rate Suicide Rate - Male Suicide Rate - Female  \
# 1               NaN          NaN                 NaN                   NaN
#
#   Education Spending (% of GDP) Annual Change.9 Arable Land -Hectares  \
# 1                           NaN             NaN                   NaN
#
#   Per Capita Percent  col
# 1        NaN     NaN  5.0
#
# [1 rows x 119 columns]

# %% [markdown]
# # Data processing

# %%
import pandas as pd
df = pd.read_csv("set.csv")
df.columns
# Out:
# Index(['Year', 'Literacy Rate(%)', 'Population ', 'Population growth rate (%)',
#        'Migrant Population (Estimated)', 'Net Migration Rate', 'Growth Rate',
#        'Inflation Rate (%)', 'Annual Change (%)', 'GNI (Billion USD)',
#        ...
#        'Military Size ', 'Annual % Change\r', 'Suicide Rate',
#        'Suicide Rate - Male', 'Suicide Rate - Female',
#        'Education Spending (% of GDP)', 'Annual Change.9',
#        'Arable Land -Hectares', 'Per Capita', 'Percent'],
#       dtype='object', length=118)

# %%
df.head(4)
# Out:
#      Year  Literacy Rate(%) Population  Population growth rate (%)  \
# 0  1980.0              26.0  83,929,765                      2.47%
# 1  1981.0              27.0  86,154,836                      2.65%
# 2  1982.0              27.8  88,555,336                      2.79%
# 3  1983.0              28.2  91,045,478                      2.81%
#
#   Migrant Population (Estimated)  Net Migration Rate Growth Rate  \
# 0                        720,000              -2.569      -8.38%
# 1                        730,000              -2.333      -9.19%
# 2                        740,000              -2.098     -10.07%
# 3                        750,000              -1.863     -11.20%
#
#   Inflation Rate (%) Annual Change (%)  GNI (Billion USD)  ... Military Size   \
# 0               0.82             -0.82              18.48  ...            NaN
# 1               7.23              6.41              21.50  ...            NaN
# ...

# %%
df.shape
# Out:
# (101, 118)

# %%
df.tail(2)
# Out:
#      Year  Literacy Rate(%) Population  Population growth rate (%)  \
# 99    NaN               NaN         NaN                        NaN
# 100   NaN               NaN         NaN                        NaN
#
#     Migrant Population (Estimated)  Net Migration Rate Growth Rate  \
# 99                             NaN                 NaN         NaN
# 100                            NaN                 NaN         NaN
#
#     Inflation Rate (%) Annual Change (%)  GNI (Billion USD)  ...  \
# 99                 NaN               NaN                NaN  ...
# 100                NaN               NaN                NaN  ...
#
#     Military Size  Annual % Change\r Suicide Rate Suicide Rate - Male  \
# 99             NaN               NaN          NaN                 NaN
# 100            NaN               NaN          NaN                 NaN
#
#     Suicide Rate - Female Education Spending (% of GDP) Annual Change.9  \
# ...

# %%
df.sample(3)
# Out:
#       Year  Literacy Rate(%)  Population  Population growth rate (%)  \
# 35  2015.0             65.14  157,830,000                        1.2
# 84     NaN               NaN          NaN                        NaN
# 68     NaN               NaN          NaN                        NaN
#
#    Migrant Population (Estimated)  Net Migration Rate Growth Rate  \
# 35                      1,400,000              -2.743      -5.09%
# 84                            NaN                 NaN         NaN
# 68                            NaN                 NaN         NaN
#
#    Inflation Rate (%) Annual Change (%)  GNI (Billion USD)  ...  \
# 35               6.19              -0.8             191.34  ...
# 84                NaN               NaN                NaN  ...
# 68                NaN               NaN                NaN  ...
#
#    Military Size  Annual % Change\r Suicide Rate Suicide Rate - Male  \
# 35     220,950.00             0.00%      340.00%             500.00%
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Literacy Rate(%)', 'Population ', 'Population growth rate (%)',
#        'Migrant Population (Estimated)', 'Net Migration Rate', 'Growth Rate',
#        'Inflation Rate (%)', 'Annual Change (%)', 'GNI (Billion USD)',
#        ...
#        'Military Size ', 'Annual % Change\r', 'Suicide Rate',
#        'Suicide Rate - Male', 'Suicide Rate - Female',
#        'Education Spending (% of GDP)', 'Annual Change.9',
#        'Arable Land -Hectares', 'Per Capita', 'Percent'],
#       dtype='object', length=118)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Columns: 118 entries, Year to Percent
# dtypes: float64(26), object(92)
# memory usage: 93.2+ KB

# %%
df.describe()
# Out:
#               Year  Literacy Rate(%)  Net Migration Rate  GNI (Billion USD)  \
# count    44.000000         44.000000           43.000000          44.000000
# mean   2001.500000         48.115455           -2.162070         120.265000
# std      12.845233         16.600579            1.028741         133.834785
# min    1980.000000         26.000000           -4.542000          18.480000
# 25%    1990.750000         33.125000           -2.721500          33.437500
# 50%    2001.500000         48.750000           -2.113000          57.450000
# 75%    2012.250000         59.325000           -1.338500         149.825000
# max    2023.000000         76.800000           -0.452000         493.930000
#
#        Number of Private Vehichles  Death Rate  Life Expectancy (years)  \
# count                          0.0   44.000000                44.000000
# mean                           NaN    8.180159                64.452955
# ...

# %%
a = df.describe(include = "all")

# %% [markdown]
# # Loc and iloc

# %%
a.loc[["top","mean"]]
# Out:
#         Year  Literacy Rate(%) Population  Population growth rate (%)  \
# top      NaN               NaN  83,929,765                       1.25
# mean  2001.5         48.115455         NaN                        NaN
#
#      Migrant Population (Estimated)  Net Migration Rate Growth Rate  \
# top                       1,400,000                 NaN      -2.08%
# mean                            NaN            -2.16207         NaN
#
#      Inflation Rate (%) Annual Change (%)  GNI (Billion USD)  ...  \
# top               5.31%              2.34                NaN  ...
# mean                NaN               NaN            120.265  ...
#
#      Military Size  Annual % Change\r Suicide Rate Suicide Rate - Male  \
# top      220,950.00             0.00%      490.00%             510.00%
# mean            NaN               NaN          NaN                 NaN
#
#      Suicide Rate - Female Education Spending (% of GDP) Annual Change.9  \
# ...

# %%
a.iloc[[0,1,2]]
# Out:
#         Year  Literacy Rate(%) Population  Population growth rate (%)  \
# count   44.0              44.0          44                         44
# unique   NaN               NaN          44                         39
# top      NaN               NaN  83,929,765                       1.25
#
#        Migrant Population (Estimated)  Net Migration Rate Growth Rate  \
# count                              44                43.0          43
# unique                             43                 NaN          42
# top                         1,400,000                 NaN      -2.08%
#
#        Inflation Rate (%) Annual Change (%)  GNI (Billion USD)  ...  \
# count                  44                44               44.0  ...
# unique                 43                41                NaN  ...
# top                 5.31%              2.34                NaN  ...
#
#        Military Size  Annual % Change\r Suicide Rate Suicide Rate - Male  \
# ...

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
df[["Year","Suicide Rate"]]
# Out:
#        Year Suicide Rate
# 0    1980.0          NaN
# 1    1981.0          NaN
# 2    1982.0          NaN
# 3    1983.0          NaN
# 4    1984.0          NaN
# 5    1985.0          NaN
# 6    1986.0          NaN
# 7    1987.0          NaN
# 8    1988.0          NaN
# 9    1989.0          NaN
# 10   1990.0          NaN
# 11   1991.0          NaN
# 12   1992.0          NaN
# 13   1993.0          NaN
# 14   1994.0          NaN
# 15   1995.0          NaN
# 16   1996.0          NaN
# 17   1997.0          NaN
# 18   1998.0          NaN
# 19   1999.0          NaN
# 20   2000.0      600.00%
# 21   2001.0      570.00%
# 22   2002.0      530.00%
# 23   2003.0      510.00%
# 24   2004.0      490.00%
# 25   2005.0      490.00%
# 26   2006.0      500.00%
# 27   2007.0      490.00%
# 28   2008.0      470.00%
# 29   2009.0      460.00%
# 30   2010.0      440.00%
# 31   2011.0      400.00%
# 32   2012.0      370.00%
# 33   2013.0      350.00%
# 34   2014.0      350.00%
# 35   2015.0      340.00%
# ...

# %% [markdown]
# # Mean , mode and median

# %%
df["Year"].mean()
# Out:
# 2001.5

# %%
x = df["Year"].mean()
df["Year"].fillna(x)
# Out:
# Series([], Name: Year, dtype: float64)

# %%
df["Year"].mode()
# Out:
# Series([], Name: Year, dtype: float64)

# %%
df["Year"].median()
# Out:
# 2001.5

# %%
df["Suicide Rate"].value_counts()
# Out:
# Suicide Rate
# 490.00%    3
# 350.00%    3
# 370.00%    2
# 340.00%    2
# 600.00%    1
# 570.00%    1
# 530.00%    1
# 510.00%    1
# 500.00%    1
# 470.00%    1
# 460.00%    1
# 440.00%    1
# 400.00%    1
# 360.00%    1
# Name: count, dtype: int64

# %%
df['Year'] = df['Year'].replace('1980', '1981')

# %%
df.dropna()
# Out:
# Empty DataFrame
# ...

# %%
df.dropna(inplace=True)

# %%
df.fillna(13)
# Out:
# Empty DataFrame
# ...

# %%
df["Year"].fillna(1988)
# Out:
# 0      1980.0
# 1      1981.0
# 2      1982.0
# 3      1983.0
# 4      1984.0
#         ...
# 96     1988.0
# 97     1988.0
# 98     1988.0
# 99     1988.0
# 100    1988.0
# Name: Year, Length: 101, dtype: float64

# %%
df.drop_duplicates(inplace=True)
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# # Importing matplotlib.pyplot

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Graphs

# %%
import pandas as pd
data = df
df = pd.DataFrame(data)
df['annual shifting agriculture'].value_counts().sort_index().plot(kind='pie',title='compony')
plt.show()

# %%
import pandas as pd
data = df
df = pd.DataFrame(data)
df['annual shifting agriculture'].value_counts().sort_index().plot(kind='bar', title='company')
plt.show()

# %%
import pandas as pd
data = df
df = pd.DataFrame(data)
df['annual shifting agriculture'].value_counts().sort_index().plot(kind='line',title='company')
plt.show()

# %%
import pandas as pd
data = df
df = pd.DataFrame(data)
df['annual shifting agriculture'].value_counts().sort_index().plot(kind='barh',title='company')
plt.show()

# %%
import pandas as pd
data = df
df = pd.DataFrame(data)
df['annual shifting agriculture'].value_counts().sort_index().plot(kind='hist',title='company')
plt.show()

# %%
import pandas as pd
data = df
df = pd.DataFrame(data)
df['annual shifting agriculture'].value_counts().sort_index().plot(kind='box',title='compony')
plt.show()

# %%
import pandas as pd
data = df
df = pd.DataFrame(data)
df['annual shifting agriculture'].value_counts().sort_index().plot(kind='area',title='compony')
plt.show()
